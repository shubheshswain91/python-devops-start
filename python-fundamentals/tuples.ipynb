# %% [markdown]
# # Tuples (`tuple`)
#
# Tuples are ordered, immutable sequences defined with parentheses `()`. Once created, their contents cannot be changed.

# %% [markdown]
# ## Characteristics and Use Cases
# - Ordered: items maintain position
# - Immutable: cannot add, remove, or change after creation
# - Useful for fixed records like coordinates, version numbers, or as dictionary keys

# %%
host_port = ("127.0.0.1", 8080)
red_rgb = (255, 0, 0)
tuple_single = ("only-value",)  # Single value tuple requires a trailing comma
print(type(tuple_single))
print(host_port)
print(tuple_single)

print(f"Host: {host_port[0]}, Port: {host_port[1]}")
print(red_rgb[-2:])  # Slicing works the same as lists
# Out:
# <class 'tuple'>
# ('127.0.0.1', 8080)
# ('only-value',)
# Host: 127.0.0.1, Port: 8080
# (0, 0)

# %% [markdown]
# ## Hands-on Exercise
# 1. Create a tuple `service_endpoint` with hostname and port values.
# 2. Print the hostname and port.
# 3. Attempt to modify an element (commented out to avoid error).

# %%
service_endpoint = ("https://api.example.com/v1/resources", 8080)
print(f"Host name: {service_endpoint[0]}, Port: {service_endpoint[1]}")
# Out:
# Host name: https://api.example.com/v1/resources, Port: 8080
